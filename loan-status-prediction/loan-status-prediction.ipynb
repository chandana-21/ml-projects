# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('loanstatus.csv')
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# ## Data Preprocessing

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.head(20)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 7   LP001014    Male     Yes         3+      Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 9   LP001020    Male     Yes          1      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 11  LP001027    Male     Yes          2      Graduate           NaN
# 12  LP001028    Male     Yes          2      Graduate            No
# ...

# %%
df = df.fillna(df.mean())
df.head(20)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 7   LP001014    Male     Yes         3+      Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 9   LP001020    Male     Yes          1      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 11  LP001027    Male     Yes          2      Graduate           NaN
# 12  LP001028    Male     Yes          2      Graduate            No
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df = df.dropna()
df.shape
# Out:
# (554, 13)

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df = df.replace({'Loan_Status': {'N':0, 'Y':1}}) # label encoding
df['Loan_Status'].head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: Loan_Status, dtype: int64

# %%
df['Dependents'].value_counts()
# Out:
# 0     319
# 1      95
# 2      94
# 3+     46
# Name: Dependents, dtype: int64

# %%
df = df.replace(to_replace = '3+', value=4)
df['Dependents'].value_counts()
# Out:
# 0    319
# 1     95
# 2     94
# 4     46
# Name: Dependents, dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
sns.countplot(x='Education',hue='Loan_Status',data=df, palette=["red", "green"])
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
sns.countplot(x='Married',hue='Loan_Status',data=df, palette=["red", "green"])
# Out:
# <AxesSubplot:xlabel='Married', ylabel='count'>

# %%
sns.countplot(x='Gender',hue='Loan_Status',data=df, palette=["red", "green"])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
# Label Encoding
from sklearn import preprocessing
categ = ['Married','Gender','Self_Employed','Property_Area','Education']
label_encoder = preprocessing.LabelEncoder()
df[categ] = df[categ].apply(label_encoder.fit_transform)
df.head()
# Out:
#     Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0  LP001002       1        0          0          0              0
# 1  LP001003       1        1          1          0              0
# 2  LP001005       1        1          0          0              1
# 3  LP001006       1        1          0          1              0
# 4  LP001008       1        0          0          0              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History  Property_Area  Loan_Status
# 0             1.0              2            1
# 1             1.0              0            0
# ...

# %%
df = df.drop(columns='Loan_ID', axis=1)
df.head(10)
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0          0          0              0             5849
# 1       1        1          1          0              0             4583
# 2       1        1          0          0              1             3000
# 3       1        1          0          1              0             2583
# 4       1        0          0          0              0             6000
# 5       1        1          2          0              1             5417
# 6       1        1          0          1              0             2333
# 7       1        1          4          0              0             3036
# 8       1        1          2          0              0             4006
# 9       1        1          1          0              0            12841
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0  146.412162             360.0             1.0
# ...

# %% [markdown]
# ## Splitting Data

# %%
X = df.drop(columns = ['Loan_Status'], axis=1)
y = df['Loan_Status']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, stratify = y, random_state=2)

# %%
X_train.shape
# Out:
# (498, 11)

# %%
X_test.shape
# Out:
# (56, 11)

# %% [markdown]
# ## Training the Model: SVM

# %%
clf = svm.SVC(kernel='linear')

# %%
from tqdm import tqdm

# %%
clf.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
# for i in tqdm(range(0, 100), desc ="Progress"):  
#     clf.fit(X_train,y_train)

# %%
X_train_prediction = clf.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,y_train)
print(training_data_accuracy)
# Out:
# 0.7931726907630522

# %%
X_test_prediction = clf.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction,y_test)
print(test_data_accuracy)
# Out:
# 0.8035714285714286

# %% [markdown]
# ## Predictive System

# %%
X_train.shape
# Out:
# (498, 11)

# %%
#todo
